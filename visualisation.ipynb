# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('diabetes-classification/train.csv')
print(data)
# Out:
#      p_id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0     316            2      112             68             22       94  34.1
# 1      25           11      143             94             33      146  36.6
# 2     710            2       93             64             32      160  38.0
# 3     658            1      120             80             48      200  38.9
# 4     542            3      128             72             25      190  32.4
# ..    ...          ...      ...            ...            ...      ...   ...
# 609    14            1      189             60             23      846  30.1
# 610   555            1       84             64             23      115  36.9
# 611   730            2       92             52              0        0  30.1
# 612   103            0      125             96              0        0  22.5
# 613   603            1      124             74             36        0  27.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data.groupby('Outcome').count()
# Out:
#          p_id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Outcome
# 0         400          400      400            400            400      400
# 1         214          214      214            214            214      214
#
#          BMI  DiabetesPedigreeFunction  Age
# Outcome
# 0        400                       400  400
# 1        214                       214  214

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('Age').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()

# %%
d2 = split_data.get_group(0)
c2 = d2.groupby('Age').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")

plt.legend()
plt.xlabel('Age')
plt.ylabel('number of individuals')
# Out:
# 50
# 50
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('BMI').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('BMI').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.xlabel('BMI')
plt.ylabel('number of individuals')
plt.legend()
# Out:
# 194
# 194

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('Pregnancies').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('Pregnancies').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('Pregnancies')
plt.ylabel('number of individuals')
# Out:
# 14
# 14
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('Glucose').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('Glucose').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('Glucose')
plt.ylabel('number of individuals')
# Out:
# 99
# 99
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('BloodPressure').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('BloodPressure').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('BloodPressure')
plt.ylabel('number of individuals')
# Out:
# 39
# 39
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('SkinThickness').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('SkinThickness').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('SkinThickness')
plt.ylabel('number of individuals')
# Out:
# 46
# 46
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('Insulin').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('Insulin').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('Insulin')
plt.ylabel('number of individuals')
# Out:
# 120
# 120
# Text(0, 0.5, 'number of individuals')

# %%
split_data = data.groupby('Outcome')
d1 = split_data.get_group(1)
c1 = d1.groupby('DiabetesPedigreeFunction').Outcome.count()
l1 = list(c1.index)
l21 = c1.values.tolist()
d2 = split_data.get_group(0)
c2 = d2.groupby('DiabetesPedigreeFunction').Outcome.count()
l = list(c2.index)
l2 = c2.values.tolist()
print(len(l))
print(len(l2))


plt.plot(l, l2, label="0")
plt.plot(l1, l21, label="1")
plt.legend()
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('number of individuals')
# Out:
# 312
# 312
# Text(0, 0.5, 'number of individuals')

# %%
features = list(data.columns)
ItemsData = []

for feature in features:
    if feature == "Pregnancies":
        featureData = list(data.Pregnancies)
        Pregnancies = []
        for item in featureData:
            if item <= 7:
                Pregnancies.append('P1')
            else:
                Pregnancies.append('P2')
    elif feature == "Glucose":
        
        featureData = list(data.Glucose)
        Glucose = []
        
        for item in featureData:
            
            if item <= 125:
                Glucose.append('G1')
            else:
                Glucose.append('G2')
        
    elif feature == "BloodPressure":
        featureData = list(data.BloodPressure)
        BloodPressure = []
        for item in featureData:
            if item <= 40:
                BloodPressure.append('B1')
            elif item > 40 and item <= 90:
                BloodPressure.append('B2')
            else:
                BloodPressure.append('B3')
    elif feature == "SkinThickness":
        featureData = list(data.SkinThickness)
        SkinThickness = []
        for item in featureData:
            if item <= 8:
                SkinThickness.append('S1')
            elif item >8 and item <= 45:
                SkinThickness.append('S2')
            else:
                SkinThickness.append('S3')
        
    elif feature == "Insulin":
        featureData = list(data.Insulin)
        Insulin = []
        for item in featureData:
            if item <= 30:
                Insulin.append('I1')
            elif item >30 and item <= 150:
                Insulin.append('I2')
            else:
                Insulin.append('I3')
        
    elif feature == "BMI":
        featureData = list(data.BMI)
        BMI = []
        for item in featureData:
            if item <= 30:
                BMI.append('BMI1')
            else:
                BMI.append('BMI2')
        
    elif feature == "DiabetesPedigreeFunction":
        featureData = list(data.DiabetesPedigreeFunction)
        DiabetesPedigreeFunction = []
        for item in featureData:
            if item <= .8:
                DiabetesPedigreeFunction.append('D1')
            else:
                DiabetesPedigreeFunction.append('D2')
        
    elif feature == "Age":
        featureData = list(data.Age)
        Age = []
        for item in featureData:
            if item <= 30:
                Age.append('A1')
            else:
                Age.append('A2')
    else:
        featureData = list(data.Outcome)
        Outcome =[]
        for item in featureData:
            if item == 0:
                Outcome.append('0')
            else:
                Outcome.append('1')

for j in range(614):
    transaction = [Pregnancies[j], Glucose[j], BloodPressure[j], SkinThickness[j], Insulin[j], BMI[j], DiabetesPedigreeFunction[j], Age[j], Outcome[j]]
    ItemsData.append(transaction)

print(len(ItemsData))
ItemsData
# Out:
# 614
# [['P1', 'G1', 'B2', 'S2', 'I2', 'BMI2', 'D1', 'A1', '0'],
#  ['P2', 'G2', 'B3', 'S2', 'I2', 'BMI2', 'D1', 'A2', '1'],
#  ['P1', 'G1', 'B2', 'S2', 'I3', 'BMI2', 'D1', 'A1', '1'],
#  ['P1', 'G1', 'B2', 'S3', 'I3', 'BMI2', 'D2', 'A2', '0'],
#  ['P1', 'G2', 'B2', 'S2', 'I3', 'BMI2', 'D1', 'A1', '1'],
#  ['P1', 'G1', 'B2', 'S1', 'I1', 'BMI1', 'D1', 'A2', '0'],
#  ['P1', 'G1', 'B1', 'S2', 'I1', 'BMI1', 'D1', 'A1', '0'],
#  ['P1', 'G1', 'B2', 'S3', 'I2', 'BMI2', 'D1', 'A1', '0'],
#  ['P1', 'G1', 'B2', 'S2', 'I2', 'BMI2', 'D1', 'A1', '0'],
#  ['P1', 'G1', 'B2', 'S2', 'I2', 'BMI2', 'D1', 'A1', '0'],
#  ['P1', 'G1', 'B2', 'S2', 'I2', 'BMI1', 'D2', 'A1', '0'],
#  ['P1', 'G2', 'B2', 'S2', 'I1', 'BMI2', 'D1', 'A1', '1'],
#  ['P1', 'G1', 'B2', 'S2', 'I1', 'BMI1', 'D1', 'A1', '0'],
#  ['P2', 'G1', 'B2', 'S2', 'I1', 'BMI2', 'D1', 'A2', '0'],
#  ['P2', 'G1', 'B2', 'S1', 'I1', 'BMI2', 'D1', 'A2', '0'],
#  ['P1', 'G1', 'B3', 'S1', 'I1', 'BMI1', 'D1', 'A1', '0'],
# ...
